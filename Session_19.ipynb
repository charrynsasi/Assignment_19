# %% [markdown]
# 1. What are the three stages to build the hypotheses or model in machine learning?

# %% [markdown]
# Answers :
#
# 1. Model building
# 2. Model testing
# 3. Applying the model

# %% [markdown]
# 2. What is the standard approach to supervised learning?

# %% [markdown]
# Answers :
#
# The standard approach to supervised learning is to split the set of data into the training and the test data set

# %% [markdown]
# 3. What is Training set and Test set?

# %% [markdown]
# Answers:
#
# Training set is an examples given to the model to learn, while Test set is used to test the accuracy of the hypotheses
# generated by the model.

# %% [markdown]
# 4. What is the general principle of an ensemble method and what is bagging and boosting in ensemble method?

# %% [markdown]
# Answers :
#
# The general principle of an ensemble method is to combine the predictions of several models built with a given
# learning algorithm in order to improve robustness over a single model.
#
# Bagging is used paralelly for improving unstable estimation or classification schemes. Bagging both can reduce errors by reducing the variance term.
#
# Boosting method is used sequentially to reduce the bias of the combined model. Boosting can reduce errors by reducing the variance term.

# %% [markdown]
# 5. How can you avoid overfitting ?

# %% [markdown]
# Answers :
#
# 1. Add more data
# 2. Use data augmentation
# 3. Use architectures that generalize well
# 4. Add regularization (mostly dropout, L1/L2 regularization are also possible)
# 5. Reduce architecture complexity.
